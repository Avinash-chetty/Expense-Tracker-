# %% [markdown]
# <a href="https://colab.research.google.com/github/Avinash-chetty/Expense-Tracker-/blob/main/Expense_Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Expense Tracker

expensesList = []  # list of expenses stored as dictionaries
print("Welcome to Expense Tracker!")

while True:
    print("==== MENU ====")
    print("1. Add Expense")
    print("2. View All Expenses")
    print("3. View Total Expense")
    print("4. Exit")

    choice = int(input("Please enter your choice: "))

    # 1. ADD EXPENSE
    if (choice == 1):
        date = input("Enter the date of expense: ")
        category = input("Enter expense category (Food, Travel, Makeup, Books): ")
        description = input("Enter expense description: ")
        amount = float(input("Enter the amount: "))

        expense = {
            "date": date,
            "category": category,
            "description": description,
            "amount": amount
        }

        expensesList.append(expense)
        print("\nExpense added successfully!")

    # 2. VIEW ALL EXPENSES
    elif (choice == 2):
        if (len(expensesList) == 0):
            print("No expenses added yet.")
        else:
            print("===== All Expenses =====")
            count = 1
            for eachExpense in expensesList:
                print(f"Expense {count} -> {eachExpense['date']},{eachExpense['category']},{eachExpense['description']},{eachExpense['amount']}")

                count =count+1

    # 3. VIEW TOTAL EXPENSE
    elif (choice == 3):
        total = 0
        for eachExpense in expensesList:
            total = total + eachExpense["amount"]

        print("\nTotal Expense =", total)

    # 4. EXIT
    elif (choice == 4):
        print("Thank you for using the Expense Tracker.")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# Welcome to Expense Tracker!
# ==== MENU ====
# 1. Add Expense
# 2. View All Expenses
# 3. View Total Expense
# 4. Exit
# Please enter your choice: 1
# Enter the date of expense: 2-3-4-2009
# Enter expense category (Food, Travel, Makeup, Books): food
# Enter expense description: chips
# Enter the amount: 200000
#
# Expense added successfully!
# ==== MENU ====
# 1. Add Expense
# 2. View All Expenses
# 3. View Total Expense
# 4. Exit
# Please enter your choice: 2
# ===== All Expenses =====
# Expense 1 -> 2-3-4-2009,food,chips,200000.0
# ==== MENU ====
# 1. Add Expense
# 2. View All Expenses
# 3. View Total Expense
# 4. Exit
# Please enter your choice: 3
#
# Total Expense = 200000.0
# ==== MENU ====
# 1. Add Expense
# 2. View All Expenses
# 3. View Total Expense
# 4. Exit
# Please enter your choice: 4
# Thank you for using the Expense Tracker.
